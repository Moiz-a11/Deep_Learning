# %%
import torch
import torch.nn as nn

# %%
inputs = torch.tensor([1.0,2.0,3.0])

# %%
neuron = nn.Linear(in_features=3,out_features=1)

# %%
output = neuron(inputs)

# %%
output
# Out:
# tensor([2.4116], grad_fn=<ViewBackward0>)

# %%
#formula varify
neuron.weight @ inputs + neuron.bias # @ means dot product
# Out:
# tensor([2.4116], grad_fn=<AddBackward0>)
