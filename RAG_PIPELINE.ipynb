# %%
# %pip install langchain langchain-core langchain-community pypdf pymupdf sentence-transformers chromadb
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: langchain in C:\Users\MOIZ\AppData\Roaming\Python\Python313\site-packages (1.4.0)
# Requirement already satisfied: langchain-core in C:\Users\MOIZ\AppData\Roaming\Python\Python313\site-packages (1.6.2)
# Requirement already satisfied: langchain-community in C:\Users\MOIZ\AppData\Roaming\Python\Python313\site-packages (0.4.2)
# Requirement already satisfied: pypdf in C:\Users\MOIZ\AppData\Roaming\Python\Python313\site-packages (6.17.0)
# Requirement already satisfied: pymupdf in C:\Users\MOIZ\AppData\Roaming\Python\Python313\site-packages (1.28.2)
# Requirement already satisfied: sentence-transformers in C:\Users\MOIZ\AppData\Roaming\Python\Python313\site-packages (5.7.0)
# Requirement already satisfied: chromadb in C:\Users\MOIZ\AppData\Roaming\Python\Python313\site-packages (1.5.9)
# Requirement already satisfied: langgraph<1.3.0,>=1.2.11 in C:\Users\MOIZ\AppData\Roaming\Python\Python313\site-packages (from langchain) (1.2.11)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in C:\Users\MOIZ\AppData\Roaming\Python\Python313\site-packages (from langchain) (2.13.4)
# Requirement already satisfied: httpx<1.0.0,>=0.23.0 in C:\ProgramData\anaconda3\Lib\site-packages (from langchain-core) (0.28.1)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in C:\ProgramData\anaconda3\Lib\site-packages (from langchain-core) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in C:\Users\MOIZ\AppData\Roaming\Python\Python313\site-packages (from langchain-core) (0.0.19)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in C:\Users\MOIZ\AppData\Roaming\Python\Python313\site-packages (from langchain-core) (0.12.1)
# Requirement already satisfied: packaging>=23.2.0 in C:\ProgramData\anaconda3\Lib\site-packages (from langchain-core) (24.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in C:\Users\MOIZ\AppData\Roaming\Python\Python313\site-packages (from langchain-core) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in C:\ProgramData\anaconda3\Lib\site-packages (from langchain-core) (9.0.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in C:\Users\MOIZ\AppData\Roaming\Python\Python313\site-packages (from langchain-core) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in C:\Users\MOIZ\AppData\Roaming\Python\Python313\site-packages (from langchain-core) (0.17.0)
# Requirement already satisfied: anyio in C:\Users\MOIZ\AppData\Roaming\Python\Python313\site-packages (from httpx<1.0.0,>=0.23.0->langchain-core) (4.14.1)
# Requirement already satisfied: certifi in C:\ProgramData\anaconda3\Lib\site-packages (from httpx<1.0.0,>=0.23.0->langchain-core) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in C:\ProgramData\anaconda3\Lib\site-packages (from httpx<1.0.0,>=0.23.0->langchain-core) (1.0.9)
# Requirement already satisfied: idna in C:\Users\MOIZ\AppData\Roaming\Python\Python313\site-packages (from httpx<1.0.0,>=0.23.0->langchain-core) (3.19)
# Requirement already satisfied: h11>=0.16 in C:\ProgramData\anaconda3\Lib\site-packages (from httpcore==1.*->httpx<1.0.0,>=0.23.0->langchain-core) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in C:\ProgramData\anaconda3\Lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core) (2.1)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=4.1.0 in C:\Users\MOIZ\AppData\Roaming\Python\Python313\site-packages (from langgraph<1.3.0,>=1.2.11->langchain) (4.2.0)
# Requirement already satisfied: langgraph-prebuilt<1.2.0,>=1.1.0 in C:\Users\MOIZ\AppData\Roaming\Python\Python313\site-packages (from langgraph<1.3.0,>=1.2.11->langchain) (1.1.0)
# Requirement already satisfied: langgraph-sdk<0.5.0,>=0.4.2 in C:\Users\MOIZ\AppData\Roaming\Python\Python313\site-packages (from langgraph<1.3.0,>=1.2.11->langchain) (0.4.4)
# Requirement already satisfied: xxhash>=3.5.0 in C:\Users\MOIZ\AppData\Roaming\Python\Python313\site-packages (from langgraph<1.3.0,>=1.2.11->langchain) (4.0.1)
# Requirement already satisfied: ormsgpack>=1.12.0 in C:\Users\MOIZ\AppData\Roaming\Python\Python313\site-packages (from langgraph-checkpoint<5.0.0,>=4.1.0->langgraph<1.3.0,>=1.2.11->langchain) (1.12.2)
# Requirement already satisfied: orjson>=3.11.5 in C:\Users\MOIZ\AppData\Roaming\Python\Python313\site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.11->langchain) (3.11.9)
# Requirement already satisfied: websockets<17,>=14 in C:\Users\MOIZ\AppData\Roaming\Python\Python313\site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.11->langchain) (16.0)
# Requirement already satisfied: distro>=1.7.0 in C:\ProgramData\anaconda3\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (1.9.0)
# Requirement already satisfied: httpx2<3,>=2 in C:\Users\MOIZ\AppData\Roaming\Python\Python313\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (2.12.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in C:\ProgramData\anaconda3\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in C:\Users\MOIZ\AppData\Roaming\Python\Python313\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (2.34.2)
# Requirement already satisfied: sniffio>=1.1 in C:\ProgramData\anaconda3\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (1.3.0)
# Requirement already satisfied: zstandard>=0.23.0 in C:\ProgramData\anaconda3\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (0.23.0)
# Requirement already satisfied: httpcore2==2.12.0 in C:\Users\MOIZ\AppData\Roaming\Python\Python313\site-packages (from httpx2<3,>=2->langsmith<1.0.0,>=0.3.45->langchain-core) (2.12.0)
# Requirement already satisfied: truststore>=0.10 in C:\ProgramData\anaconda3\Lib\site-packages (from httpx2<3,>=2->langsmith<1.0.0,>=0.3.45->langchain-core) (0.10.0)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\ProgramData\anaconda3\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.6.0)
# Requirement already satisfied: pydantic-core==2.46.4 in C:\Users\MOIZ\AppData\Roaming\Python\Python313\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in C:\Users\MOIZ\AppData\Roaming\Python\Python313\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in C:\Users\MOIZ\AppData\Roaming\Python\Python313\site-packages (from langchain-community) (3.14.3)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in C:\Users\MOIZ\AppData\Roaming\Python\Python313\site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.7 in C:\Users\MOIZ\AppData\Roaming\Python\Python313\site-packages (from langchain-community) (1.0.8)
# Requirement already satisfied: numpy>=2.1.0 in C:\Users\MOIZ\AppData\Roaming\Python\Python313\site-packages (from langchain-community) (2.4.3)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in C:\Users\MOIZ\AppData\Roaming\Python\Python313\site-packages (from langchain-community) (2.15.0)
# Requirement already satisfied: sqlalchemy<3.0.0,>=1.4.0 in C:\Users\MOIZ\AppData\Roaming\Python\Python313\site-packages (from langchain-community) (2.0.51)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in C:\Users\MOIZ\AppData\Roaming\Python\Python313\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.7.1)
# Requirement already satisfied: aiosignal>=1.4.0 in C:\Users\MOIZ\AppData\Roaming\Python\Python313\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in C:\ProgramData\anaconda3\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in C:\Users\MOIZ\AppData\Roaming\Python\Python313\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in C:\Users\MOIZ\AppData\Roaming\Python\Python313\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in C:\Users\MOIZ\AppData\Roaming\Python\Python313\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in C:\Users\MOIZ\AppData\Roaming\Python\Python313\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.24.5)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.2 in C:\Users\MOIZ\AppData\Roaming\Python\Python313\site-packages (from langchain-classic<2.0.0,>=1.0.7->langchain-community) (1.1.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in C:\ProgramData\anaconda3\Lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.1.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\ProgramData\anaconda3\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.26 in C:\ProgramData\anaconda3\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core) (2.3.0)
# Requirement already satisfied: greenlet>=1 in C:\Users\MOIZ\AppData\Roaming\Python\Python313\site-packages (from sqlalchemy<3.0.0,>=1.4.0->langchain-community) (3.5.4)
# Requirement already satisfied: transformers<6.0.0,>=4.41.0 in C:\Users\MOIZ\AppData\Roaming\Python\Python313\site-packages (from sentence-transformers) (5.12.1)
# Requirement already satisfied: tokenizers>=0.19 in C:\Users\MOIZ\AppData\Roaming\Python\Python313\site-packages (from sentence-transformers) (0.22.2)
# Requirement already satisfied: huggingface-hub>=0.23.0 in C:\Users\MOIZ\AppData\Roaming\Python\Python313\site-packages (from sentence-transformers) (1.29.0)
# Requirement already satisfied: torch>=1.11.0 in C:\Users\MOIZ\AppData\Roaming\Python\Python313\site-packages (from sentence-transformers) (2.10.0)
# Requirement already satisfied: scikit-learn>=0.22.0 in C:\Users\MOIZ\AppData\Roaming\Python\Python313\site-packages (from sentence-transformers) (1.9.0)
# Requirement already satisfied: scipy>=1.0.0 in C:\Users\MOIZ\AppData\Roaming\Python\Python313\site-packages (from sentence-transformers) (1.18.0)
# Requirement already satisfied: tqdm>=4.0.0 in C:\ProgramData\anaconda3\Lib\site-packages (from sentence-transformers) (4.67.1)
# Requirement already satisfied: regex>=2025.10.22 in C:\Users\MOIZ\AppData\Roaming\Python\Python313\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (2026.5.9)
# Requirement already satisfied: typer in C:\Users\MOIZ\AppData\Roaming\Python\Python313\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.25.1)
# Requirement already satisfied: safetensors>=0.4.3 in C:\Users\MOIZ\AppData\Roaming\Python\Python313\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.8.0)
# Requirement already satisfied: click<9.0.0,>=8.4.2 in C:\Users\MOIZ\AppData\Roaming\Python\Python313\site-packages (from huggingface-hub>=0.23.0->sentence-transformers) (8.5.0)
# Requirement already satisfied: filelock>=3.10.0 in C:\Users\MOIZ\AppData\Roaming\Python\Python313\site-packages (from huggingface-hub>=0.23.0->sentence-transformers) (3.25.1)
# Requirement already satisfied: fsspec>=2023.5.0 in C:\Users\MOIZ\AppData\Roaming\Python\Python313\site-packages (from huggingface-hub>=0.23.0->sentence-transformers) (2026.2.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.2 in C:\Users\MOIZ\AppData\Roaming\Python\Python313\site-packages (from huggingface-hub>=0.23.0->sentence-transformers) (1.6.0)
# Requirement already satisfied: build>=1.0.3 in C:\Users\MOIZ\AppData\Roaming\Python\Python313\site-packages (from chromadb) (1.5.0)
# Requirement already satisfied: pybase64>=1.4.1 in C:\Users\MOIZ\AppData\Roaming\Python\Python313\site-packages (from chromadb) (1.4.3)
# Requirement already satisfied: uvicorn>=0.18.3 in C:\Users\MOIZ\AppData\Roaming\Python\Python313\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.52.4)
# Requirement already satisfied: onnxruntime>=1.14.1 in C:\Users\MOIZ\AppData\Roaming\Python\Python313\site-packages (from chromadb) (1.28.0)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in C:\Users\MOIZ\AppData\Roaming\Python\Python313\site-packages (from chromadb) (1.44.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in C:\Users\MOIZ\AppData\Roaming\Python\Python313\site-packages (from chromadb) (1.44.0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in C:\Users\MOIZ\AppData\Roaming\Python\Python313\site-packages (from chromadb) (1.44.0)
# Requirement already satisfied: pypika>=0.48.9 in C:\Users\MOIZ\AppData\Roaming\Python\Python313\site-packages (from chromadb) (0.51.1)
# Requirement already satisfied: overrides>=7.3.1 in C:\Users\MOIZ\AppData\Roaming\Python\Python313\site-packages (from chromadb) (7.7.0)
# Requirement already satisfied: importlib-resources in C:\Users\MOIZ\AppData\Roaming\Python\Python313\site-packages (from chromadb) (7.1.0)
# Requirement already satisfied: grpcio>=1.58.0 in C:\Users\MOIZ\AppData\Roaming\Python\Python313\site-packages (from chromadb) (1.83.0)
# Requirement already satisfied: bcrypt>=4.0.1 in C:\Users\MOIZ\AppData\Roaming\Python\Python313\site-packages (from chromadb) (5.0.0)
# Requirement already satisfied: kubernetes>=28.1.0 in C:\Users\MOIZ\AppData\Roaming\Python\Python313\site-packages (from chromadb) (36.0.3)
# Requirement already satisfied: mmh3>=4.0.1 in C:\Users\MOIZ\AppData\Roaming\Python\Python313\site-packages (from chromadb) (5.2.1)
# Requirement already satisfied: rich>=10.11.0 in C:\ProgramData\anaconda3\Lib\site-packages (from chromadb) (13.9.4)
# Requirement already satisfied: jsonschema>=4.19.0 in C:\ProgramData\anaconda3\Lib\site-packages (from chromadb) (4.23.0)
# Requirement already satisfied: pyproject_hooks in C:\Users\MOIZ\AppData\Roaming\Python\Python313\site-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: colorama in C:\ProgramData\anaconda3\Lib\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in C:\ProgramData\anaconda3\Lib\site-packages (from jsonschema>=4.19.0->chromadb) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in C:\ProgramData\anaconda3\Lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in C:\ProgramData\anaconda3\Lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.22.3)
# Requirement already satisfied: six>=1.9.0 in C:\ProgramData\anaconda3\Lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in C:\ProgramData\anaconda3\Lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in C:\Users\MOIZ\AppData\Roaming\Python\Python313\site-packages (from kubernetes>=28.1.0->chromadb) (1.9.0)
# Requirement already satisfied: requests-oauthlib in C:\Users\MOIZ\AppData\Roaming\Python\Python313\site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: durationpy>=0.7 in C:\Users\MOIZ\AppData\Roaming\Python\Python313\site-packages (from kubernetes>=28.1.0->chromadb) (0.10)
# Requirement already satisfied: flatbuffers in C:\Users\MOIZ\AppData\Roaming\Python\Python313\site-packages (from onnxruntime>=1.14.1->chromadb) (25.12.19)
# Requirement already satisfied: protobuf>=4.25.8 in C:\ProgramData\anaconda3\Lib\site-packages (from onnxruntime>=1.14.1->chromadb) (5.29.3)
# Requirement already satisfied: googleapis-common-protos~=1.57 in C:\Users\MOIZ\AppData\Roaming\Python\Python313\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.75.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.44.0 in C:\Users\MOIZ\AppData\Roaming\Python\Python313\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.44.0)
# Requirement already satisfied: opentelemetry-proto==1.44.0 in C:\Users\MOIZ\AppData\Roaming\Python\Python313\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.44.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.65b0 in C:\Users\MOIZ\AppData\Roaming\Python\Python313\site-packages (from opentelemetry-sdk>=1.2.0->chromadb) (0.65b0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in C:\ProgramData\anaconda3\Lib\site-packages (from rich>=10.11.0->chromadb) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in C:\ProgramData\anaconda3\Lib\site-packages (from rich>=10.11.0->chromadb) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in C:\ProgramData\anaconda3\Lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.0)
# Requirement already satisfied: joblib>=1.4.0 in C:\Users\MOIZ\AppData\Roaming\Python\Python313\site-packages (from scikit-learn>=0.22.0->sentence-transformers) (1.5.3)
# Requirement already satisfied: narwhals>=2.0.1 in C:\Users\MOIZ\AppData\Roaming\Python\Python313\site-packages (from scikit-learn>=0.22.0->sentence-transformers) (2.25.0)
# Requirement already satisfied: threadpoolctl>=3.5.0 in C:\Users\MOIZ\AppData\Roaming\Python\Python313\site-packages (from scikit-learn>=0.22.0->sentence-transformers) (3.6.0)
# Requirement already satisfied: sympy>=1.13.3 in C:\Users\MOIZ\AppData\Roaming\Python\Python313\site-packages (from torch>=1.11.0->sentence-transformers) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in C:\Users\MOIZ\AppData\Roaming\Python\Python313\site-packages (from torch>=1.11.0->sentence-transformers) (3.6.1)
# Requirement already satisfied: jinja2 in C:\Users\MOIZ\AppData\Roaming\Python\Python313\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: setuptools in C:\Users\MOIZ\AppData\Roaming\Python\Python313\site-packages (from torch>=1.11.0->sentence-transformers) (82.0.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in C:\Users\MOIZ\AppData\Roaming\Python\Python313\site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: shellingham>=1.3.0 in C:\ProgramData\anaconda3\Lib\site-packages (from typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (1.5.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in C:\Users\MOIZ\AppData\Roaming\Python\Python313\site-packages (from typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (0.0.4)
# Requirement already satisfied: httptools>=0.8.0 in C:\Users\MOIZ\AppData\Roaming\Python\Python313\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.8.0)
# Requirement already satisfied: watchfiles>=0.20 in C:\Users\MOIZ\AppData\Roaming\Python\Python313\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in C:\Users\MOIZ\AppData\Roaming\Python\Python313\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.3)
# Requirement already satisfied: oauthlib>=3.0.0 in C:\Users\MOIZ\AppData\Roaming\Python\Python313\site-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb) (3.3.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import langchain
import chromadb
import sentence_transformers

print("All packages installed successfully!")
# Out:
# All packages installed successfully!

# %%
from langchain_core.documents import Document

# %%
sample_doc = Document(
    page_content="Hello World!",
    metadata={"source": "https://www.google.com"}
)

# %%
sample_doc
# Out:
# Document(metadata={'source': 'https://www.google.com'}, page_content='Hello World!')

# %%
type(sample_doc)
# Out:
# langchain_core.documents.base.Document

# %%
# Text data
from langchain_community.document_loaders.text import TextLoader

loader = TextLoader("data/python.txt", encoding="utf-8")

# %%
document = loader.load()

# %%
document
# Out:
# [Document(metadata={'source': 'data/python.txt'}, page_content='Python is a high-level, interpreted programming language that has become one of the most popular and widely used languages in the world. Created by Guido van Rossum and first released in 1991, Python emphasizes simplicity and readability, making it easy for beginners to learn while remaining powerful for experienced developers. Its clean and concise syntax allows programmers to write fewer lines of code compared to many other languages, enhancing productivity and maintainability. Python supports multiple programming paradigms, including procedural, object-oriented, and functional programming, which makes it versatile for a wide range of applications.\nSome key features and benefits of Python include:\n* Ease of Learning: Simple syntax and readability make Python beginner-friendly.\n* Versatility: Suitable for web development, data analysis, artificial intelligence, machine learning, scientific computing, automation, and more.\n* Extensive Libraries and Frameworks: Libraries like NumPy, Pandas, Matplotlib, and frameworks like Django and Flask accelerate development.\n* Cross-Platform Compatibility: Python programs can run on Windows, macOS, Linux, and other platforms without major modifications.\n* Strong Community Support: A large and active community provides extensive documentation, tutorials, and open-source resources.\n* Integration Capabilities: Python can integrate with other languages like C/C++, Java, and supports REST APIs, databases, and cloud services.\n* Rapid Prototyping: Python allows for quick development and testing of ideas due to its interpreted nature and ease of use.\nPython’s combination of simplicity, flexibility, and a rich ecosystem makes it a top choice for developers, researchers, and enterprises worldwide, whether building small scripts or complex, large-scale applications.')]

# %%
# PDF data
from langchain_community.document_loaders.pdf import PyPDFLoader

pdf_loader = PyPDFLoader("data/research.pdf")

document = pdf_loader.load()
document
